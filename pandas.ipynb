# %%
import pandas as pd
import pandas as pd
a = ["Jwalitha", 'Ramya',
'Durga','Jahnavi','Lahari','Sunny','Dhanush']
r = pd.Series(a, index = [67,43,44,89,34,45,23])
print(r)
# Out:
# 67    Jwalitha
# 43       Ramya
# 44       Durga
# 89     Jahnavi
# 34      Lahari
# 45       Sunny
# 23     Dhanush
# dtype: object

# %%
df = pd.read_excel("/content/drive/MyDrive/diabetes (1).xlsx")
print(df)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
df.head(5)
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
df.tail(4)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative

# %%
print(df.shape)
# Out:
# (768, 9)

# %%
df.groupby(["age","class"]).size()
# Out:
# age  class
# 21   tested_negative    58
#      tested_positive     5
# 22   tested_negative    61
#      tested_positive    11
# 23   tested_negative    31
#                         ..
# 68   tested_negative     1
# 69   tested_negative     2
# 70   tested_positive     1
# 72   tested_negative     1
# 81   tested_negative     1
# Length: 96, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.plot(df['age'])
plt.xlabel("age")
plt.ylabel("class")
plt.title("age vs class")
plt.show()

# %%
l1=list(df.columns)
print(l1)
# Out:
# ['preg', 'plas', 'pres', 'skin', 'insu', 'mass', 'pedi', 'age', 'class']

# %%
print(df[df.index==0])
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive

# %%
print(df[df.index.isin(range(2,5))])
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive
